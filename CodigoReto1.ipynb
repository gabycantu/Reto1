# %%
#Importar e instalar liberías
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
import pandas as pd
import numpy as np
import matplotlib as plt
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#Cargar archivo 
#datos=pd.read_csv("Ventas_totales_supermercados.csv")
datos=pd.read_csv("Ventas_totales_supermercados.csv", index_col=0)
datos
# Out:
#                ventas_precios_corrientes  ventas_precios_constantes  \
# indice_tiempo
# 2017-01-01                       27858.9                    27477.3
# 2017-02-01                       25994.2                    25223.4
# 2017-03-01                       27780.0                    26334.3
# 2017-04-01                       29134.3                    27045.9
# 2017-05-01                       27969.0                    25631.9
# ...                                  ...                        ...
# 2022-01-01                      154517.1                    25463.4
# 2022-02-01                      152202.6                    23802.1
# 2022-03-01                      168982.5                    24612.4
# 2022-04-01                      177148.1                    24140.5
# 2022-05-01                      179639.2                    23234.2
#
#                ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# indice_tiempo
# ...

# %%
#No es posible aplicar filtro por variables cualitativas
filtro1=df[df["Sexo"] == "Mujeres"]
filtro1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/gaby/Desktop/Proyecto/Reto1/CodigoReto1.ipynb Cell 3 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/gaby/Desktop/Proyecto/Reto1/CodigoReto1.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> #No es posible aplicar filtro por variables cualitativas
# ----> <a href='vscode-notebook-cell:/Users/gaby/Desktop/Proyecto/Reto1/CodigoReto1.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> filtro1=df[df["Sexo"] == "Mujeres"]
#       <a href='vscode-notebook-cell:/Users/gaby/Desktop/Proyecto/Reto1/CodigoReto1.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> filtro1
#
# NameError: name 'df' is not defined

# %%
#Filtro por filas
#filtro2= df.iloc[300:302,: ]
filtro2=datos.iloc[ [10, 20, 30,40,50,60] , : ]  #filas no consecutivas 
filtro2
filtro2.to_csv("filtro2.csv")

# %%
#Filtro por columnas
filtro3=datos.iloc[ : , 4:7]
#filtro3=df.iloc[ : , [1,4,6]]  #columnas no consecutivas 
filtro3
filtro3.to_csv("filtro3.csv")

# %%
#Filtro por cabecera
filtro5=datos.head(8)
filtro5
filtro5.to_csv("filtro5.csv")

# %%
#FILTROS BASICOS PARA VARIABLES CUANTITATIVAS
#Filtro por comparacion
filtro6=datos[datos["ventas_precios_constantes"] > 25000]
filtro6
filtro6.to_csv("filtro6.csv")

# %%
#Filtro de filas vs columnas 
filtro4=datos.loc[["2017-01-01","2022-03-01"], ["ventas_precios_corrientes"]]
filtro4
filtro4.to_csv("filtro4.csv")
# Out:
#                ventas_precios_corrientes
# indice_tiempo
# 2017-01-01                       27858.9
# 2022-03-01                      168982.5

# %%
#Crear un dataframe a partir de fichero Excel
# %pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
